# %% [markdown]
# ![image.png](attachment:579004fe-acca-441e-9982-5d4459230be3.png)

# %% [markdown]
# ![image.png](attachment:dc340a99-5c5d-47df-b307-24edb357f581.png)

# %% [markdown]
# **IMPORTING THE LIBRARIES**

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# **READING THE FILE**

# %%
df =  pd.read_csv("Unemployment in India.csv")

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %% [markdown]
# **EXPLORATORY DATA ANALYSIS**

# %%
df.shape
# Out:
# (768, 7)

# %%
df.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                         float64
#  Estimated Labour Participation Rate (%)    float64
# Area                                         object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Region                                      28
#  Date                                       28
#  Frequency                                  28
#  Estimated Unemployment Rate (%)            28
#  Estimated Employed                         28
#  Estimated Labour Participation Rate (%)    28
# Area                                        28
# dtype: int64

# %%
df = df.dropna(how='any')

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df.columns = ['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate',
       'Estimated Employed', 'Estimated Labour Participation Rate',
       'Area']

# %%
df.columns # columns are renamed
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Area'],
#       dtype='object')

# %%
df['Region'].value_counts()
# Out:
# Region
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
df['Frequency'].value_counts()
# Out:
# Frequency
# Monthly     381
#  Monthly    359
# Name: count, dtype: int64

# %%
df['Frequency'] = df['Frequency'].replace(' Monthly','Monthly')

# %%
df['Frequency'].value_counts()
# Out:
# Frequency
# Monthly    740
# Name: count, dtype: int64

# %%
df['Area'].value_counts()
# Out:
# Area
# Urban    381
# Rural    359
# Name: count, dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'],dayfirst=True) # converting the date column to date format

# %%
df.dtypes
# Out:
# Region                                         object
# Date                                   datetime64[ns]
# Frequency                                      object
# Estimated Unemployment Rate                   float64
# Estimated Employed                            float64
# Estimated Labour Participation Rate           float64
# Area                                           object
# dtype: object

# %%
df['Year'] = df['Date'].dt.year # addding a new column named Year

# %%
df.head()
# Out:
#            Region       Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2019-05-31   Monthly                         3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                         3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                         3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                         3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                         5.17
#
#    Estimated Employed  Estimated Labour Participation Rate   Area  Year
# 0          11999139.0                                43.24  Rural  2019
# 1          11755881.0                                42.05  Rural  2019
# 2          12086707.0                                43.50  Rural  2019
# 3          12285693.0                                43.97  Rural  2019
# 4          12256762.0                                44.68  Rural  2019

# %%
df['Year'].value_counts()
# Out:
# Year
# 2019    430
# 2020    310
# Name: count, dtype: int64

# %% [markdown]
# **VISUALIZATION**

# %% [markdown]
# *HISTOGRAM*

# %%
columns = list(df)[0:8]
df[columns].hist(bins=80,figsize = (12,50),layout=(14,2))
plt.show()

# %% [markdown]
# *PAIRPLOT*

# %%
sns.pairplot(df,diag_kind ='kde')
plt.show()

# %%
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate',
#        'Estimated Employed', 'Estimated Labour Participation Rate', 'Area',
#        'Year'],
#       dtype='object')

# %%
df['Region'].value_counts()
# Out:
# Region
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: count, dtype: int64

# %%
df['Year'].value_counts()
# Out:
# Year
# 2019    430
# 2020    310
# Name: count, dtype: int64

# %%
df['Area'].value_counts()
# Out:
# Area
# Urban    381
# Rural    359
# Name: count, dtype: int64

# %% [markdown]
# # ANALYSING THE RATE OF UNEMPLOYMENT

# %% [markdown]
# **GETTING THE UNEMPLOYMENT RATE BASED ON REGIONS**

# %%
un_delhi = df[df['Region'] == 'Delhi']['Estimated Unemployment Rate'].values

# %%
un_delhi.mean().round(1)
# Out:
# 16.5

# %%
ue_kerala = df[df['Region'] == 'Kerala']['Estimated Unemployment Rate'].values

# %%
ue_kerala.mean().round(1)
# Out:
# 10.1

# %%
ue_tn = df[df['Region'] == 'Tamil Nadu']['Estimated Unemployment Rate'].values

# %%
ue_tn.mean().round(1)
# Out:
# 9.3

# %% [markdown]
# ***REPORT ON UNEMPLOYMENT RATE BASED ON REGIONS***
#
# * Average Unemployment Rate in Delhi = 16.5
# * Average Unemployment Rate in Kerala = 10.1
# * Average Unemployment Rate in Tamil Nadu = 9.3

# %% [markdown]
# **GETTING UNEMPLOYMENT RATE  BASED ON YEAR**

# %%
ue_2019 = df[df['Year'] == 2019]['Estimated Unemployment Rate'].values

# %%
ue_2019.mean().round(1)
# Out:
# 9.4

# %%
ue_2020 = df[df['Year'] == 2020]['Estimated Unemployment Rate'].values

# %%
ue_2020.mean().round(1)
# Out:
# 15.1

# %% [markdown]
# ***REPORT ON UNEMPLOYMENT RATE BASED ON YEAR***
#
# * Average Unemployment Rate in 2019 = 9.4
# * Average Unemployment Rate in 2020 = 15.1

# %% [markdown]
# **GETTING UNEMPLYMENT RATE BASED ON AREA**

# %%
rural = df[df['Area'] == 'Rural']['Estimated Unemployment Rate'].values

# %%
rural.mean().round(1)
# Out:
# 10.3

# %%
urban= df[df['Area'] == 'Urban']['Estimated Unemployment Rate'].values

# %%
urban.mean().round(1)
# Out:
# 13.2

# %% [markdown]
# ***REPORT ON UNEMPLOYMENT RATE BASED ON AREA***
#
# * Average Unemployment Rate in urban area  = 13.2
# * Average Unemployment Rate in rural area = 10.2

# %% [markdown]
# # ANALYSING THE ESTIMATED EMPLOYMENT

# %% [markdown]
# **GETTING ESTIMATED EMPLOYED BASED ON REGION**

# %%
delhi_emp = df[df['Region'] == 'Delhi']['Estimated Employed'].values

# %%
delhi_emp.mean().round(1)
# Out:
# 2627512.9

# %%
tn_emp = df[df['Region'] == 'Tamil Nadu']['Estimated Employed'].values

# %%
tn_emp.mean().round(1)
# Out:
# 12269546.8

# %%
kerala_emp = df[df['Region'] == 'Kerala']['Estimated Employed'].values

# %%
kerala_emp.mean().round(1)
# Out:
# 4425899.5

# %% [markdown]
# ***REPORT ON ESTIMATED EMPLOYMENT BASED ON REGIONS***
#
# * Average Estimated Employment in Delhi = 2627512.9
# * Average Estimated Employment in Kerala = 4425899.5
# * Average Estimated Employment in Tamil Nadu = 12269546.8

# %% [markdown]
# **GETTING ESTIMATED EMPLOYED BASED ON YEAR**

# %%
emp_2019 = df[df['Year'] == 2019]['Estimated Employed'].values

# %%
emp_2019.mean().round(1)
# Out:
# 7422976.5

# %%
emp_2020 = df[df['Year'] == 2020]['Estimated Employed'].values

# %%
emp_2020.mean().round(1)
# Out:
# 6901356.6

# %% [markdown]
# ***REPORT ON ESTIMATED EMPLOYMEENT BASED ON YEAR***
#
# * Average Estimated Employment in 2019 = 7422976.5
# * Average Estimated Employment in 2020 = 6901356.6

# %% [markdown]
# **GETTING UNEMPLYMENT RATE BASED ON AREA**

# %%
rural_emp = df[df['Area'] == 'Rural']['Estimated Employed'].values

# %%
rural_emp.mean().round(1)
# Out:
# 10192852.6

# %%
urban_emp = df[df['Area'] == 'Urban']['Estimated Employed'].values

# %%
urban_emp.mean().round(1)
# Out:
# 4388625.6

# %% [markdown]
# ***REPORT ON ESTMATED EMPLOYMENT BASED ON AREA***
#
# * Average Estimated Employment in urban area  = 4388625.6
# * Average Estimated Employment  in rural area = 10192852.6

# %% [markdown]
# # ANALYSING THE RATE OF LABOUR PARTICIPATION

# %% [markdown]
# **GETTING ESTIMATED LABOUR PARTICIPATION RATE  BASED ON REGION**

# %%
delhi_emp_part = df[df['Region'] == 'Delhi']['Estimated Labour Participation Rate'].values

# %%
delhi_emp_part.mean().round(1)
# Out:
# 38.9

# %%
Tn_emp_part = df[df['Region'] == 'Tamil Nadu']['Estimated Labour Participation Rate'].values

# %%
Tn_emp_part.mean().round(1)
# Out:
# 40.9

# %%
kerala_emp_part = df[df['Region'] == 'Kerala']['Estimated Labour Participation Rate'].values

# %%
kerala_emp_part.mean().round(1)
# Out:
# 34.9

# %% [markdown]
# ***REPORT ON RATE OF LABOUR PARTICIPATION BASED ON REGIONS***
#
# * Average Rate of Labour Participation in Delhi = 38.9
# * Average Rate of Labour Participation in Kerala = 34.9
# * Average Rate of Labour Participation in Tamil Nadu = 40.9

# %% [markdown]
# **GETTING ESTIMATED LABOUR PARTICIPATION RATE BASED ON YEAR**

# %%
emp_part_2019 = df[df['Year'] == 2019]['Estimated Labour Participation Rate'].values

# %%
emp_part_2019.mean().round(1)
# Out:
# 43.9

# %%
emp_part_2020 = df[df['Year'] == 2020]['Estimated Labour Participation Rate'].values

# %%
emp_part_2020.mean().round(1)
# Out:
# 40.9

# %% [markdown]
# ***REPORT ON RATE OF LABOUR PARTICIPATION BASED ON YEAR***
#
# * Average Rate of Labour Participation in 2019 = 43.9
# * Average Rate of Labour Participation in 2020 = 40.9

# %% [markdown]
# **GETTING ESTIMATED LABOUR PARTICIPATION RATE BASED ON AREA**

# %%
rural_emp_part = df[df['Area'] == 'Rural']['Estimated Labour Participation Rate'].values

# %%
rural_emp_part.mean().round(1)
# Out:
# 44.5

# %%
urban_emp_part = df[df['Area'] == 'Urban']['Estimated Labour Participation Rate'].values

# %%
urban_emp_part.mean().round(1)
# Out:
# 40.9

# %% [markdown]
# ***REPORT ON RATE OF LABOUR PARTICIPATION BASED ON AREA***
#
# * Average Rate of Labour Participation in urban area  = 40.9
# * Average Rate of Labour Participation in rural area = 44.5
