# %% [markdown]
# ![image.png](attachment:ba0a1648-41a8-462c-80c9-1a076bf29168.png)

# %% [markdown]
# ![image.png](attachment:9b0eed6a-16ee-43d0-9f65-48d2cd46f525.png)

# %% [markdown]
# **IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split

# %% [markdown]
# **LOADING THE DATA**

# %%
df = pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %% [markdown]
# **EXPLORATORY DATA ANLYSIS**

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df.shape
# Out:
# (200, 4)

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **VISUALIZATION**

# %%
columns = list(df)[0:9]
df[columns].hist(bins=80,figsize = (12,50),layout=(14,2))
plt.show()

# %%
sns.pairplot(df,diag_kind ='kde')
plt.show()

# %% [markdown]
# **SPLITTING THE DATASET**

# %%
x = df.drop('Sales',axis=1)
y = df['Sales']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state=1)

# %%
x_train.shape
# Out:
# (140, 3)

# %%
x_test.shape
# Out:
# (60, 3)

# %%
y_train.shape
# Out:
# (140,)

# %%
y_test.shape
# Out:
# (60,)

# %% [markdown]
# **MODEL BUILDING**

# %% [markdown]
# **LINEAR REGRESSOR ALGORITHM**

# %%
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_train,y_train)
# Out:
# 0.8850053786777522

# %% [markdown]
# **RANDOM FOREST REGRESSOR**

# %%
rfcl = RandomForestRegressor(n_estimators = 50 , random_state = 1 , max_features =12)

# %%
rfcl = rfcl.fit(x_train,y_train)

# %%
rfcl.score(x_train,y_train)
# Out:
# 0.9960057623053442

# %%
print("The Accuracy using Random Forest Regressor is ",(rfcl.score(x_test,y_test)*100).round(1))
# Out:
# The Accuracy using Random Forest Regressor is  98.2
